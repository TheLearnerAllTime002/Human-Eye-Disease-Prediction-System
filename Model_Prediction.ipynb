# %%
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
import numpy as np
import os

# %%
import tensorflow as tf

# --- Recreate your custom F1Score class exactly as before ---
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super().__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + 1e-8))

    def reset_state(self):
        self.precision.reset_state()
        self.recall.reset_state()

# --- Load your trained model safely ---

# %%
model = tf.keras.models.load_model(
    "Trained_Model.h5",
    custom_objects={"F1Score": F1Score}
)

# %%
img_path = "./test/DME/DME-30521-58.jpeg"
img = tf.keras.utils.load_img(img_path, target_size=(224, 224))
x = tf.keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
preds
# Out:
# array([[0.01178126, 0.96999717, 0.00517674, 0.01304489]], dtype=float32)

# %%
class_name = os.listdir("./test")
class_name
# Out:
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %%
result_index = np.argmax(preds)
class_name[result_index]
# Out:
# 'DME'
